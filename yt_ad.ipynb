# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('F:\\youtube_ad\\youtube_ad_revenue_dataset.csv')

# %%
df
# Out:
#         video_id                        date  views   likes  comments  \
# 0       vid_3092  2024-09-24 10:50:40.993199   9936  1221.0     320.0
# 1       vid_3459  2024-09-22 10:50:40.993199  10017   642.0     346.0
# 2       vid_4784  2024-11-21 10:50:40.993199  10097  1979.0     187.0
# 3       vid_4078  2025-01-28 10:50:40.993199  10034  1191.0     242.0
# 4       vid_3522  2025-04-28 10:50:40.993199   9889  1858.0     477.0
# ...          ...                         ...    ...     ...       ...
# 122395  vid_2902  2024-12-14 10:50:40.993199   9853  1673.0     147.0
# 122396  vid_3890  2024-07-13 10:50:40.993199  10128  1709.0      63.0
# 122397  vid_3934  2024-06-10 10:50:40.993199  10267   700.0       NaN
# 122398  vid_4260  2024-12-22 10:50:40.993199  10240  1616.0     106.0
# 122399  vid_1056  2024-06-25 10:50:40.993199   9931   770.0       NaN
#
#         watch_time_minutes  video_length_minutes  subscribers       category  \
# ...

# %%
df.shape # How many rows & columns
# Out:
# (122400, 12)

# %%
df.info() #Data types, missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122400 entries, 0 to 122399
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   video_id              122400 non-null  object
#  1   date                  122400 non-null  object
#  2   views                 122400 non-null  int64
#  3   likes                 116283 non-null  float64
#  4   comments              116288 non-null  float64
#  5   watch_time_minutes    116295 non-null  float64
#  6   video_length_minutes  122400 non-null  float64
#  7   subscribers           122400 non-null  int64
#  8   category              122400 non-null  object
#  9   device                122400 non-null  object
#  10  country               122400 non-null  object
#  11  ad_revenue_usd        122400 non-null  float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 11.2+ MB

# %%
df.describe() # Summary statistics for numerical columns
# Out:
#                views          likes       comments  watch_time_minutes  \
# count  122400.000000  116283.000000  116288.000000       116295.000000
# mean     9999.856283    1099.633618     274.396636        37543.827721
# std        99.881260     519.424089     129.741739        12987.724246
# min      9521.000000     195.000000      48.000000        14659.105562
# 25%      9933.000000     650.000000     162.000000        26366.320569
# 50%     10000.000000    1103.000000     274.000000        37531.990337
# 75%     10067.000000    1547.000000     387.000000        48777.782090
# max     10468.000000    2061.000000     515.000000        61557.670089
#
#        video_length_minutes    subscribers  ad_revenue_usd
# count         122400.000000  122400.000000   122400.000000
# mean              16.014165  502191.719902      252.727210
# std                8.083790  288397.470103       61.957052
# min                2.000142    1005.000000      126.590603
# ...

# %% [markdown]
# # **EDA (Exploratory Data Analysis)**
#                                               (Identify trends, correlations, and outliers.)

# %% [markdown]
# ##  **Performance insight**
# which metrics drive revenue most with distributions and relation with revenue

# %% [markdown]
#  **LIKES**

# %%
# Likes distribution
plt.figure(figsize=(7,4))
sns.histplot(df['likes'], kde=True, bins=30)
plt.title("Distribution of likes")
plt.show()

# %% [markdown]
# Shows how many videos have a certain number of likes.Positive skew indicates few videos get very high likes.
# KDE curve helps visualize the trend and concentration of likes across videos.

# %%
# Likes vs Ad Revenue
plt.figure(figsize=(7,4))
sns.scatterplot(x=df['likes'], y=df['ad_revenue_usd'])
plt.title("Likes vs Ad Revenue")
plt.show()

# %% [markdown]
# This shows if videos with more likes also earn more. A positive trend suggests likes can boost engagement → revenue.

# %% [markdown]
# **VIEWS**

# %%
# Views distribution
plt.figure(figsize=(7,4))
sns.histplot(df['views'], kde=True, bins=30)
plt.title("Distribution of views")
plt.show()

# %% [markdown]
# Plots the frequency of videos for different view counts,bins=30 splits the X-axis (views) into 30 intervals.
# kde=True adds a smooth curve to see the overall distribution.Helps identify whether most videos have low, medium, or high views, and spot outliers.

# %%
#Views vs Ad Revenue
plt.figure(figsize=(7,4))
sns.scatterplot(x=df['views'], y=df['ad_revenue_usd'])
plt.title("Views vs Ad Revenue")
plt.show()

# %% [markdown]
# Each point is a video.
# This plot helps check whether more views generally lead to higher revenue

# %% [markdown]
# **COMMENTS**

# %%
# Comments distribution
plt.figure(figsize=(7,4))
sns.histplot(df['comments'], kde=True, bins=30)
plt.title("Distribution of comments")
plt.show()

# %% [markdown]
# Shows the spread of comments per video.Helps understand viewer engagement; few highly-commented videos might stand out as outliers.Useful for comparing comments vs views/likes later.

# %%
#Comments vs Ad Revenue
plt.figure(figsize=(7,4))
sns.scatterplot(x=df['comments'], y=df['ad_revenue_usd'])
plt.title("Comments vs Ad Revenue")
plt.show()

# %% [markdown]
# This checks whether more audience interaction (comments) contributes to better monetization.

# %% [markdown]
# **WATCH TIME**

# %%
# Watch time distribution
plt.figure(figsize=(7,4))
sns.histplot(df['watch_time_minutes'], kde=True, bins=30)
plt.title("Distribution of watch_time_minutes")
plt.show()

# %% [markdown]
# Shows how long viewers watch videos.Peaks indicate the most common watch time range.Outliers may indicate extremely long or short watch times affecting engagement metrics.

# %%
# Watch Time vs Ad Revenue
plt.figure(figsize=(7,4))
sns.scatterplot(x=df['watch_time_minutes'], y=df['ad_revenue_usd'])
plt.title("Watch Time (minutes) vs Ad Revenue")
plt.show()

# %% [markdown]
# Watch time usually has a strong direct effect on revenue, since advertisers pay for audience attention. A steeper upward slope indicates higher impact.

# %% [markdown]
# **VIDEO LENGTH**

# %%
# Video length distribution
plt.figure(figsize=(7,4))
sns.histplot(df['video_length_minutes'], kde=True, bins=30)
plt.title("Distribution of video_length_minutes")
plt.show()

# %% [markdown]
# Plots the length of videos in the dataset.Helps understand whether creators prefer short, medium, or long videos.Useful for analyzing how video length may affect views, watch time, or ad revenue.

# %%
#Video Length vs Ad Revenue
plt.figure(figsize=(7,4))
sns.scatterplot(x=df['video_length_minutes'], y=df['ad_revenue_usd'])
plt.title("Video Length (minutes) vs Ad Revenue")
plt.show()

# %% [markdown]
# This checks whether longer videos earn more. Longer videos can host multiple ads, but very long ones may not always guarantee higher revenue.

# %% [markdown]
# # **2. Channel Feature (subscribers)**

# %%
#Distribution of Subscribers
plt.figure(figsize=(7,4))
sns.histplot(df['subscribers'], kde=True, bins=30)
plt.title("Distribution of Subscribers")
plt.show()

# %% [markdown]
# Shows how the number of subscribers is spread across all channels. You can see which channels have low, medium, or high subscribers.

# %%
#Subscribers vs Ad Revenue
sns.scatterplot(x=df['subscribers'], y=df['ad_revenue_usd'])
plt.title("Subscribers vs Ad Revenue")
plt.show()

# %% [markdown]
# Shows the relationship between subscribers and ad revenue; more subscribers usually mean higher revenue, visible as an upward trend.

# %% [markdown]
# # **3. Context Features (category, device, country)**

# %%
#Revenue by Category
plt.figure(figsize=(10,5))
sns.boxplot(x='category', y='ad_revenue_usd', data=df)
plt.xticks(rotation=45)
plt.title("Revenue by Category")
plt.show()

# %% [markdown]
# Shows how ad revenue varies for each video category. The boxplot displays median, spread, and outliers for each category.

# %%
#Revenue by device
plt.figure(figsize=(8,5))
sns.boxplot(x='device', y='ad_revenue_usd', data=df)
plt.title("Revenue by Device")
plt.show()

# %% [markdown]
# Shows how ad revenue differs across devices (e.g., mobile, desktop). Boxes help compare revenue distribution.

# %%
#Revenue by Top 10 Countries
plt.figure(figsize=(12,6))
top_countries = df['country'].value_counts().head(10).index
sns.boxplot(x='country', y='ad_revenue_usd', data=df[df['country'].isin(top_countries)])
plt.xticks(rotation=45)
plt.title("Revenue by Top 10 Countries")
plt.show()

# %% [markdown]
# Compares ad revenue for the top 10 countries. Helps see which countries generate higher or lower revenue and identify outliers.

# %% [markdown]
# # **CORRELATION MATRIX**

# %%
corr = df[['views','likes','comments','watch_time_minutes','video_length_minutes','subscribers','ad_revenue_usd']].corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Interpretation:
#
# Values close to 1 or -1 → strong positive/negative correlation
#
# Example: More watch_time might strongly correlate with ad revenue.

# %% [markdown]
# # **OUTLIER DETECTION**

# %%
#LIKES
plt.figure(figsize=(8,5))
sns.violinplot(x=df['likes'], inner=None, color='skyblue')

lower = df['likes'].quantile(0.01)
upper = df['likes'].quantile(0.99)
outliers = df[(df['likes'] < lower) | (df['likes'] > upper)]['likes']

sns.scatterplot(x=outliers, y=[0]*len(outliers), color='red', s=10)
plt.title("Distribution + Outliers of Likes")
plt.show()

print(f"Likes - Outliers count: {len(outliers)}")
print(f"Lower bound (1%): {lower}, Upper bound (99%): {upper}\n")
# Out:
# Likes - Outliers count: 2236
# Lower bound (1%): 217.0, Upper bound (99%): 1983.0

# %% [markdown]
#                                                              Number of likes per video.
#
# Violin Plot Use: Shows how many videos have a certain number of likes. Positive skew indicates few videos get very high likes.
#
#
# Outlier Points: Red points show videos with exceptionally high or low likes, indicating high engagement content or poor engagement videos.

# %%
#VIEWS
plt.figure(figsize=(8,5))
sns.violinplot(x=df['views'], inner=None, color='skyblue')

lower = df['views'].quantile(0.01)
upper = df['views'].quantile(0.99)
outliers = df[(df['views'] < lower) | (df['views'] > upper)]['views']

sns.scatterplot(x=outliers, y=[0]*len(outliers), color='red', s=10)
plt.title("Distribution + Outliers of Views")
plt.show()

print(f"Views - Outliers count: {len(outliers)}")
print(f"Lower bound (1%): {lower}, Upper bound (99%): {upper}\n")
# Out:
# Views - Outliers count: 2386
# Lower bound (1%): 9767.0, Upper bound (99%): 10233.0

# %% [markdown]
#                                                  Number of times a video has been watched.
# Violin Plot Use: Shows the distribution of views across all videos.Helps identify whether most videos have low, medium, or high views.
#
# Outlier Points: Red points indicate extremely high or low views. These are videos that are either viral hits or very unpopular, which can skew revenue predictions

# %%
#COMMENTS
plt.figure(figsize=(8,5))
sns.violinplot(x=df['comments'], inner=None, color='skyblue')

lower = df['comments'].quantile(0.01)
upper = df['comments'].quantile(0.99)
outliers = df[(df['comments'] < lower) | (df['comments'] > upper)]['comments']

sns.scatterplot(x=outliers, y=[0]*len(outliers), color='red', s=10)
plt.title("Distribution + Outliers of Comments")
plt.show()

print(f"Comments - Outliers count: {len(outliers)}")
print(f"Lower bound (1%): {lower}, Upper bound (99%): {upper}\n")
# Out:
# Comments - Outliers count: 2000
# Lower bound (1%): 54.0, Upper bound (99%): 496.0

# %% [markdown]
#                                                               Number of comments per video.
#
# Violin Plot Use: Shows distribution of audience interaction. Reveals whether most videos have few comments or whether engagement is uniform.
#
# Outlier Points: Videos with very high comments (e.g., controversial or viral videos) are highlighted. These outliers can significantly impact ad revenue.

# %%
#WATCH TIME MIN
plt.figure(figsize=(8,5))
sns.violinplot(x=df['watch_time_minutes'], inner=None, color='skyblue')

lower = df['watch_time_minutes'].quantile(0.01)
upper = df['watch_time_minutes'].quantile(0.99)
outliers = df[(df['watch_time_minutes'] < lower) | (df['watch_time_minutes'] > upper)]['watch_time_minutes']

sns.scatterplot(x=outliers, y=[0]*len(outliers), color='red', s=10)
plt.title("Distribution + Outliers of Watch Time Minutes")
plt.show()

print(f"Watch Time - Outliers count: {len(outliers)}")
print(f"Lower bound (1%): {lower}, Upper bound (99%): {upper}\n")
# Out:
# Watch Time - Outliers count: 2326
# Lower bound (1%): 15438.393200754528, Upper bound (99%): 59664.95015476675

# %% [markdown]
#                                                      Total minutes viewers spent watching the video.
#
# Violin Plot Use: Shows how long viewers typically watch videos. Helps identify if most videos have short, medium, or long watch time.
#
# Outlier Points: Red points indicate videos with extremely high or low watch time, which strongly affects ad revenue because advertisers pay for attention.

# %%
#VIDEO LENGTH MIN
plt.figure(figsize=(8,5))
sns.violinplot(x=df['video_length_minutes'], inner=None, color='skyblue')

lower = df['video_length_minutes'].quantile(0.01)
upper = df['video_length_minutes'].quantile(0.99)
outliers = df[(df['video_length_minutes'] < lower) | (df['video_length_minutes'] > upper)]['video_length_minutes']

sns.scatterplot(x=outliers, y=[0]*len(outliers), color='red', s=10)
plt.title("Distribution + Outliers of Video Length Minutes")
plt.show()

print(f"Video Length - Outliers count: {len(outliers)}")
print(f"Lower bound (1%): {lower}, Upper bound (99%): {upper}\n")
# Out:
# Video Length - Outliers count: 2447
# Lower bound (1%): 2.2765463045826246, Upper bound (99%): 29.72094900616685

# %% [markdown]
#                                                               Duration of the video in minutes.
#
# Violin Plot Use: Shows the distribution of video lengths creators are uploading. Can reveal trends (e.g., most videos are 5–15 minutes).
#
# Outlier Points: Very long or very short videos appear as red points. Long videos might host multiple ads, but very long or very short videos can affect engagement.

# %%
#SUBSCRIBERS
plt.figure(figsize=(8,5))
sns.violinplot(x=df['subscribers'], inner=None, color='skyblue')

lower = df['subscribers'].quantile(0.01)
upper = df['subscribers'].quantile(0.99)
outliers = df[(df['subscribers'] < lower) | (df['subscribers'] > upper)]['subscribers']

sns.scatterplot(x=outliers, y=[0]*len(outliers), color='red', s=10)
plt.title("Distribution + Outliers of Subscribers")
plt.show()

print(f"Subscribers - Outliers count: {len(outliers)}")
print(f"Lower bound (1%): {lower}, Upper bound (99%): {upper}\n")
# Out:
# Subscribers - Outliers count: 2448
# Lower bound (1%): 11134.98, Upper bound (99%): 990059.04

# %% [markdown]
#                                           Number of subscribers of the channel uploading the video.
#
# Violin Plot Use: Shows distribution of channel sizes. Reveals if most videos come from small, medium, or large channels.
#
# Outlier Points: Channels with extremely high subscribers are red points.These are usually top creators who might earn significantly higher ad revenue.

# %% [markdown]
# SUMMARY

# %% [markdown]
# This code checks each numeric column and tells you how many extremely low or high values (outliers) there are using the 1%–99% rule.
#
# Boxplot = simple, fast, ideal for numeric summary & outliers.
#
# Violin + Outlier points = best for EDA

# %% [markdown]
# PREPROCESSING

# %%
df.duplicated().sum()
# Out:
# np.int64(2400)

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
# Missing values check
df.isnull().sum()
# Out:
# video_id                   0
# date                       0
# views                      0
# likes                   6000
# comments                6000
# watch_time_minutes      6000
# video_length_minutes       0
# subscribers                0
# category                   0
# device                     0
# country                    0
# ad_revenue_usd             0
# dtype: int64

# %%
# Fill missing with mean (numerical columns)
df['likes'] = df['likes'].fillna(df['likes'].mean())
df['comments'] = df['comments'].fillna(df['comments'].mean())
df['watch_time_minutes'] = df['watch_time_minutes'].fillna(df['watch_time_minutes'].mean())

# %%
df.isnull().sum()
# Out:
# video_id                0
# date                    0
# views                   0
# likes                   0
# comments                0
# watch_time_minutes      0
# video_length_minutes    0
# subscribers             0
# category                0
# device                  0
# country                 0
# ad_revenue_usd          0
# dtype: int64

# %%
# Drop video_id – not useful for modeling
df.drop(columns=['video_id'], inplace=True)

# %%
# Convert to datetime
df['date'] = pd.to_datetime(df['date'])

# %%
# Extract useful features
df['upload_month'] = df['date'].dt.month
df['upload_dayofweek'] = df['date'].dt.dayofweek
df['upload_day'] = df['date'].dt.day

# %%
# Drop original date column
df.drop(columns=['date'], inplace=True)

# %% [markdown]
# Linear Regression cannot handle raw dates, but numeric features extracted from date can capture trends or seasonal effects.

# %%
df
# Out:
#         views   likes    comments  watch_time_minutes  video_length_minutes  \
# 0        9936  1221.0  320.000000        26497.214184              2.862137
# 1       10017   642.0  346.000000        15209.747445             23.738069
# 2       10097  1979.0  187.000000        57332.658498             26.200634
# 3       10034  1191.0  242.000000        31334.517771             11.770340
# 4        9889  1858.0  477.000000        15665.666434              6.635854
# ...       ...     ...         ...                 ...                   ...
# 122395   9853  1673.0  147.000000        42075.704885             25.490195
# 122396  10128  1709.0   63.000000        57563.703040             16.229133
# 122397  10267   700.0  274.349842        27549.714659             23.822365
# 122398  10240  1616.0  106.000000        56967.384382              7.753099
# 122399   9931   770.0  274.349842        38466.837135             27.305703
#
# ...

# %% [markdown]
# # **Categorical Encoding**

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['category'] = le.fit_transform(df['category'])
df['device'] = le.fit_transform(df['device'])
df['country'] = le.fit_transform(df['country'])

# %%
df.head()
# Out:
#    views   likes  comments  watch_time_minutes  video_length_minutes  \
# 0   9936  1221.0     320.0        26497.214184              2.862137
# 1  10017   642.0     346.0        15209.747445             23.738069
# 2  10097  1979.0     187.0        57332.658498             26.200634
# 3  10034  1191.0     242.0        31334.517771             11.770340
# 4   9889  1858.0     477.0        15665.666434              6.635854
#
#    subscribers  category  device  country  ad_revenue_usd  upload_month  \
# 0       228086         1       2        3      203.178237             9
# 1       736015         2       3        1      140.880508             9
# 2       240534         0       2        1      360.134008            11
# 3       434482         1       1        4      224.638261             1
# 4        42030         0       1        1      165.514388             4
#
#    upload_dayofweek  upload_day
# 0                 1          24
# 1                 6          22
# ...

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# Create a new feature – Engagement Rate
#
# This feature shows how engaged viewers are relative to total views.

# %%
# Engagement rate = (likes + comments) / views
df['engagement_rate'] = (df['likes'] + df['comments']) / df['views']
df[['views', 'likes', 'comments', 'engagement_rate']].head()
# Out:
#    views   likes  comments  engagement_rate
# 0   9936  1221.0     320.0         0.155093
# 1  10017   642.0     346.0         0.098632
# 2  10097  1979.0     187.0         0.214519
# 3  10034  1191.0     242.0         0.142814
# 4   9889  1858.0     477.0         0.236121

# %%
# Watch ratio = total watch time / video length
df['watch_ratio'] = df['watch_time_minutes'] / df['video_length_minutes']

# Quick check
df[['watch_time_minutes', 'video_length_minutes', 'watch_ratio']].head()
# Out:
#    watch_time_minutes  video_length_minutes  watch_ratio
# 0        26497.214184              2.862137  9257.844017
# 1        15209.747445             23.738069   640.732307
# 2        57332.658498             26.200634  2188.216490
# 3        31334.517771             11.770340  2662.159087
# 4        15665.666434              6.635854  2360.761216

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# StandardScaler ensures all numeric features are on the same scale for Linear Regression

# %%
numeric_cols = ['views', 'likes', 'comments', 'watch_time_minutes', 
                'video_length_minutes', 'subscribers']

scale_cols = numeric_cols + ['engagement_rate', 'watch_ratio']

# %%
scaler = StandardScaler()
df[scale_cols] = scaler.fit_transform(df[scale_cols])

# %%
df[scale_cols].head()
# Out:
#       views     likes  comments  watch_time_minutes  video_length_minutes  \
# 0 -0.638847  0.239775  0.360982           -0.872393             -1.627204
# 1  0.171818 -0.903658  0.566579           -1.764055              0.954887
# 2  0.972474  1.736705 -0.690726            1.563477              1.259475
# 3  0.341957  0.180530 -0.255809           -0.490266             -0.525371
# 4 -1.109233  1.497749  1.602472           -1.728039             -1.160443
#
#    subscribers  engagement_rate  watch_ratio
# 0    -0.950903         0.339207     1.557181
# 1     0.810515        -0.743237    -0.826693
# 2    -0.907735         1.478520    -0.398590
# 3    -0.235154         0.103813    -0.267477
# 4    -1.596116         1.892665    -0.350857

# %%
df
# Out:
#            views     likes      comments  watch_time_minutes  \
# 0      -0.638847  0.239775  3.609822e-01           -0.872393
# 1       0.171818 -0.903658  5.665792e-01           -1.764055
# 2       0.972474  1.736705 -6.907257e-01            1.563477
# 3       0.341957  0.180530 -2.558089e-01           -0.490266
# 4      -1.109233  1.497749  1.602472e+00           -1.728039
# ...          ...       ...           ...                 ...
# 122395 -1.469529  1.132404 -1.007029e+00            0.358242
# 122396  1.282729  1.203498 -1.671265e+00            1.581729
# 122397  2.673870 -0.789117  4.494937e-16           -0.789250
# 122398  2.403648  1.019838 -1.331239e+00            1.534622
# 122399 -0.688888 -0.650878  4.494937e-16            0.073157
#
#         video_length_minutes  subscribers  category  device  country  \
# 0                  -1.627204    -0.950903         1       2        3
# 1                   0.954887     0.810515         2       3        1
# ...

# %%
import pandas as pd

# assuming df is your cleaned dataframe
df.to_csv(r"F:\youtube_ad\clean_youtube_data.csv", index=False)
print("Preprocessed data saved as clean_youtube_data.csv")
# Out:
# Preprocessed data saved as clean_youtube_data.csv
